# %%
# Flask Web Methods and Templates Notebook

# Question 1: Explain GET and POST methods
"""
GET:
- Used to request data from a server
- Parameters visible in URL
- Limited data capacity
- Bookmarkable/cacheable
Example: Loading a webpage

POST:
- Used to send data to server
- Parameters not shown in URL
- No data size limits
- Not bookmarkable
Example: Submitting a form
"""

# Question 2: Why is request used in Flask?
"""
The request object in Flask:
- Accesses incoming request data
- Handles form submissions
- Gets query parameters
- Reads JSON data
- Accesses files/uploads
Example: request.form['username'] gets form input
"""

# Question 3: Why is redirect() used in Flask?
"""
redirect() is used to:
- Navigate users to different routes
- After form submissions
- After authentication
- For URL routing logic
Prevents duplicate form submissions
Example: redirect('/dashboard') after login
"""

# Question 4: Flask templates and render_template()
"""
Templates:
- HTML files with dynamic content
- Allow separating Python and HTML
- Support template inheritance

render_template():
- Processes template files
- Passes variables to templates
- Returns complete HTML
Example: return render_template('home.html', title='Home')
"""
