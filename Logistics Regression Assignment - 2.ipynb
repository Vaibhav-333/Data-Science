# %%
# Hyperparameter Tuning and Data Leakage Notebook

# Question 1: Purpose and Working of GridSearchCV
"""
Purpose:
- Exhaustively searches all specified hyperparameter combinations
- Finds optimal hyperparameters for ML models
- Performs cross-validation to evaluate each combination

How it works:
1. Define parameter grid (e.g., {'C': [1,10], 'kernel': ['linear','rbf']})
2. Evaluates all possible combinations
3. Uses k-fold cross-validation for each combination
4. Selects parameters with best performance metric
5. Returns trained model with best parameters
"""

# Question 2: GridSearchCV vs RandomizedSearchCV
"""
Key Differences:
1. Search Strategy:
   - GridSearch: Exhaustive search
   - Randomized: Random sampling of parameter space

2. Computation:
   - GridSearch: More computationally expensive
   - Randomized: More efficient for large spaces

3. Coverage:
   - GridSearch: Systematic but may miss optimal points
   - Randomized: Better for exploring large spaces

When to Choose:
- GridSearch: Small parameter spaces (<10 combinations)
- RandomizedSearch: Large parameter spaces or limited compute resources
"""

# Question 3: Data Leakage in Machine Learning
"""
What is Data Leakage:
- When information from outside training data influences model
- Causes overly optimistic performance estimates
- Leads to poor generalization in production

Example:
- Using future data to predict past events
- Including test set statistics in feature scaling
- Preprocessing entire dataset before train-test split

Why Problematic:
- Inflates model performance metrics
- Creates unrealistic expectations
- Results in models that fail in real-world use
"""
